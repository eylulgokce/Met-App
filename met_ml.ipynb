# %% [markdown]
# <a href="https://colab.research.google.com/github/eylulgokce/Met-App/blob/main/met_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MET ML
#
# Download the dataset from "https://archive.ics.uci.edu/dataset/344/heterogeneity+activity+recognition", prepare it for modeling, train and evaluate machine learning models such as Random Forest, Support Vector Machine, Gradient Boosting, and Neural Network models. We will compare their performance, select the best model, and export the selected model and the feature extraction/post-processing pipeline.

# %% [markdown]
# ## Data preparation
#
# Download the dataset, extract the files.

# %%
import pandas as pd
import os

# dataset path
dataset_path = 'HHAR/Activity_Recognition_exp/Activity recognition exp/Phones_accelerometer.csv'

# Check if the dataset file already exists
if not os.path.exists(dataset_path):
    print("Dataset not found locally. Downloading and unzipping...")
    # Download the dataset
    # !wget https://archive.ics.uci.edu/static/public/344/heterogeneity+activity+recognition.zip -O heterogeneity+activity+recognition.zip

    # Unzip the dataset
    # !unzip heterogeneity+activity+recognition.zip

    # Create directories for unzipping nested files
    os.makedirs('HHAR/Activity_Recognition_exp', exist_ok=True)
    os.makedirs('HHAR/Still_exp', exist_ok=True)

    # Unzip the nested zip files
    # !unzip 'Activity recognition exp.zip' -d HHAR/Activity_Recognition_exp
    # !unzip 'Still exp.zip' -d HHAR/Still_exp
else:
    print("Dataset found locally. Skipping download and unzip.")

try:
    df_full = pd.read_csv(dataset_path)
    print("Full DataFrame loaded successfully.")

    print("\nFirst 5 rows of the full DataFrame:")
    display(df_full.head())
    print("\nFull DataFrame Info:")
    display(df_full.info())
except FileNotFoundError:
    print(f"Error: Dataset not found at {dataset_path}. Please make sure the file is in the correct directory.")
    df_full = None # Ensure df_full is None if loading fails
# Out:
# Dataset not found locally. Downloading and unzipping...
# --2025-08-21 08:59:59--  https://archive.ics.uci.edu/static/public/344/heterogeneity+activity+recognition.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘heterogeneity+activity+recognition.zip’
#
# heterogeneity+activ     [     <=>            ] 784.01M  26.8MB/s    in 22s
#
# 2025-08-21 09:00:22 (35.5 MB/s) - ‘heterogeneity+activity+recognition.zip’ saved [822098071]
#
# Archive:  heterogeneity+activity+recognition.zip
#  extracting: Activity recognition exp.zip
#  extracting: Still exp.zip
# Archive:  Activity recognition exp.zip
#    creating: HHAR/Activity_Recognition_exp/Activity recognition exp/
#   inflating: HHAR/Activity_Recognition_exp/Activity recognition exp/.DS_Store
#    creating: HHAR/Activity_Recognition_exp/__MACOSX/
#    creating: HHAR/Activity_Recognition_exp/__MACOSX/Activity recognition exp/
#   inflating: HHAR/Activity_Recognition_exp/__MACOSX/Activity recognition exp/._.DS_Store
#   inflating: HHAR/Activity_Recognition_exp/Activity recognition exp/Phones_accelerometer.csv
#   inflating: HHAR/Activity_Recognition_exp/Activity recognition exp/Phones_gyroscope.csv
#   inflating: HHAR/Activity_Recognition_exp/Activity recognition exp/readme.txt
#   inflating: HHAR/Activity_Recognition_exp/__MACOSX/Activity recognition exp/._readme.txt
#   inflating: HHAR/Activity_Recognition_exp/Activity recognition exp/Watch_accelerometer.csv
#   inflating: HHAR/Activity_Recognition_exp/Activity recognition exp/Watch_gyroscope.csv
# Archive:  Still exp.zip
#    creating: HHAR/Still_exp/Still exp/
#   inflating: HHAR/Still_exp/Still exp/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/
#    creating: HHAR/Still_exp/__MACOSX/Still exp/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/._.DS_Store
#    creating: HHAR/Still_exp/Still exp/Phoneonback/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/._.DS_Store
#    creating: HHAR/Still_exp/Still exp/Phoneonback/3Renault-AH/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/3Renault-AH/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/3Renault-AH/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/3Renault-AH/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/3Renault-AH/Samsung-Galaxy-S3 Mini.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/gear_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/gear_1/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/gear_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/gear_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/gear_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/gear_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/gear_2/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/iphone6_s/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/iphone6_s/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/iphone6_s/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/iphone6_s/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/iphone6_s/iphone-6_s_locked.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/iphone6_s/iphone-6_s_unlocked.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/iphone6_s2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/iphone6_s2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/iphone6_s2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/iphone6_s2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/iphone6_s2/iphone-6_s_locked.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/iphone6_s2/iphone-6_s_unlocked.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-101/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-101/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-101/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-101/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-101/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-103/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-103/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-103/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-103/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-103/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-108/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-108/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-108/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-108/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-108/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-115/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-115/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-115/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-115/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-115/Samsung-Galaxy-Nexus.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-116/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-116/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-116/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-116/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-116/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-118/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-118/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-118/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-118/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-118/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-119/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-119/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-119/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-119/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-119/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-120/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-120/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-120/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-120/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-120/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-123/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-123/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-123/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-123/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-123/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-124/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-124/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-124/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-124/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-124/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-126/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-126/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-126/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-126/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-126/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-128/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-128/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-128/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-128/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-128/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-131/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-131/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-131/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-131/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-131/Samsung-Galaxy-Nexus.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-132/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-132/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-132/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-132/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-132/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-133/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-133/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-133/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-133/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-133/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-134/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-134/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-134/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-134/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-134/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-135/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-135/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-135/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-135/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-135/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-137/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-137/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-137/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-137/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-137/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-139/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-139/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-139/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-139/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-139/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-140/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-140/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-140/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-140/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-140/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-141/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-141/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-141/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-141/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-141/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-144/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-144/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-144/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-144/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-144/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-149/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-149/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-149/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-149/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-149/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/it-151/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-151/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-151/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/it-151/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/it-151/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/lg_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/lg_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/lg_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/lg_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/lg_1/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/lg_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/lg_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/lg_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/lg_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/lg_2/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/nexus4_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/nexus4_2/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonback/no-name/
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/no-name/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/no-name/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonback/no-name/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/no-name/HTC-Nexus-One.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/no-name/LG-Nexus4.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/no-name/LG-Optimus-2X.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/no-name/Samsung-Galaxy-Pocket+.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/no-name/Samsung-Galaxy-Tab10.1.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonback/x-sense.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/._.DS_Store
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/3Renault-AH/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/3Renault-AH/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/3Renault-AH/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/3Renault-AH/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/3Renault-AH/Samsung-Galaxy-S3 Mini.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/gear_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/gear_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/gear_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/gear_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/gear_1/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/gear_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/gear_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/gear_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/gear_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/gear_2/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-101/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-101/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-101/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-101/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-101/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-103/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-103/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-103/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-103/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-103/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-108/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-108/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-108/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-108/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-108/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-116/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-116/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-116/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-116/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-116/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-118/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-118/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-118/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-118/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-118/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-119/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-119/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-119/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-119/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-119/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-120/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-120/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-120/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-120/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-120/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-123/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-123/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-123/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-123/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-123/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-124/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-124/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-124/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-124/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-124/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-126/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-126/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-126/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-126/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-126/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-128/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-128/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-128/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-128/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-128/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-131/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-131/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-131/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-131/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-131/Samsung-Galaxy-Nexus.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-132/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-132/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-132/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-132/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-132/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-133/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-133/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-133/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-133/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-133/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-135/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-135/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-135/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-135/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-135/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-137/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-137/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-137/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-137/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-137/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-139/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-139/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-139/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-139/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-139/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-140/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-140/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-140/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-140/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-140/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-141/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-141/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-141/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-141/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-141/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-144/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-144/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-144/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-144/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-144/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-149/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-149/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-149/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-149/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-149/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/it-151/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-151/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-151/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/it-151/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/it-151/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/lg_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/lg_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/lg_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/lg_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/lg_1/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/lg_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/lg_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/lg_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonbottom/lg_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/lg_2/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonbottom/no-name/
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/no-name/HTC-Nexus-One.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/no-name/LG-Nexus4.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/no-name/Samsung-Galaxy-Pocket+.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/no-name/Samsung-Galaxy-Tab10.1.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonbottom/x-sense.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/._.DS_Store
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/111837-0/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/111837-0/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/3Renault-AH/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/3Renault-AH/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/3Renault-AH/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/3Renault-AH/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/3Renault-AH/Samsung-Galaxy-S3 Mini.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/gear_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/gear_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/gear_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/gear_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/gear_1/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/gear_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/gear_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/gear_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/gear_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/gear_2/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-101/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-101/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-101/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-101/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-101/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-103/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-103/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-103/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-103/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-103/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-108/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-108/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-108/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-108/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-108/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-116/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-116/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-116/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-116/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-116/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-118/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-118/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-118/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-118/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-118/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-119/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-119/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-119/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-119/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-119/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-120/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-120/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-120/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-120/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-120/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-123/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-123/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-123/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-123/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-123/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-124/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-124/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-124/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-124/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-124/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-126/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-126/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-126/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-126/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-126/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-128/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-128/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-128/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-128/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-128/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-131/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-131/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-131/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-131/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-131/Samsung-Galaxy-Nexus.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-132/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-132/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-132/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-132/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-132/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-133/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-133/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-133/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-133/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-133/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-135/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-135/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-135/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-135/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-135/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-137/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-137/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-137/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-137/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-137/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-139/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-139/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-139/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-139/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-139/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-140/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-140/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-140/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-140/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-140/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-141/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-141/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-141/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-141/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-141/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-144/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-144/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-144/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-144/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-144/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-149/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-149/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-149/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-149/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-149/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/it-151/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-151/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-151/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/it-151/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/it-151/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/lg_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/lg_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/lg_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/lg_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/lg_1/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/lg_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/lg_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/lg_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/lg_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/lg_2/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/no-name/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/no-name/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/no-name/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/no-name/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/no-name/LG-Nexus4.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/no-name/Samsung-Galaxy-Pocket+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonfront/SamsungGalaxyTab10.1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/SamsungGalaxyTab10.1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/SamsungGalaxyTab10.1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonfront/SamsungGalaxyTab10.1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/SamsungGalaxyTab10.1/Samsung-Galaxy-Tab10.1.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonfront/x-sense.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/._.DS_Store
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/111837-0/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/111837-0/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/3Renault-AH/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/3Renault-AH/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/3Renault-AH/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/3Renault-AH/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/3Renault-AH/Samsung-Galaxy-S3 Mini.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/gear_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/gear_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/gear_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/gear_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/gear_1/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/gear_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/gear_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/gear_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/gear_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/gear_2/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-101/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-101/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-101/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-101/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-101/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-103/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-103/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-103/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-103/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-103/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-108/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-108/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-108/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-108/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-108/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-116/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-116/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-116/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-116/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-116/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-118/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-118/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-118/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-118/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-118/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-119/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-119/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-119/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-119/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-119/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-120/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-120/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-120/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-120/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-120/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-123/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-123/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-123/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-123/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-123/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-124/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-124/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-124/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-124/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-124/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-126/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-126/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-126/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-126/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-126/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-128/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-128/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-128/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-128/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-128/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-131/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-131/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-131/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-131/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-131/Samsung-Galaxy-Nexus.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-132/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-132/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-132/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-132/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-132/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-133/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-133/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-133/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-133/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-133/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-135/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-135/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-135/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-135/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-135/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-137/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-137/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-137/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-137/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-137/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-139/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-139/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-139/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-139/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-139/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-140/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-140/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-140/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-140/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-140/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-141/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-141/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-141/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-141/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-141/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-144/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-144/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-144/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-144/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-144/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-149/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-149/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-149/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-149/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-149/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/it-151/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-151/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-151/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/it-151/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/it-151/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/lg_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/lg_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/lg_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/lg_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/lg_1/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/lg_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/lg_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/lg_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/lg_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/lg_2/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonleft/SamsungGalaxyTab10.1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/SamsungGalaxyTab10.1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/SamsungGalaxyTab10.1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonleft/SamsungGalaxyTab10.1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/SamsungGalaxyTab10.1/Samsung-Galaxy-Tab10.1.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonleft/x-sense.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/._.DS_Store
#    creating: HHAR/Still_exp/Still exp/Phoneonright/3Renault-AH/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/3Renault-AH/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/3Renault-AH/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/3Renault-AH/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/3Renault-AH/Samsung-Galaxy-S3 Mini.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/gear_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/gear_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/gear_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/gear_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/gear_1/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/gear_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/gear_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/gear_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/gear_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/gear_2/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/it-101/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-101/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-101/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-101/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-101/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/it-103/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-103/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-103/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-103/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-103/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/it-108/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-108/.DS_Store
# ...
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-135/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/it-137/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-137/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-137/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-137/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-137/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/it-139/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-139/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-139/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-139/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-139/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/it-140/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-140/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-140/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-140/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-140/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/it-141/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-141/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-141/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-141/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-141/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/it-144/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-144/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-144/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-144/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-144/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/it-149/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-149/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-149/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-149/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-149/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/it-151/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-151/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-151/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/it-151/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/it-151/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/lg_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/lg_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/lg_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/lg_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/lg_1/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/lg_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/lg_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/lg_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/lg_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/lg_2/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/no-name/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/no-name/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/no-name/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/no-name/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/no-name/HTC-Nexus-One.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/no-name/LG-Nexus4.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/no-name/Samsung-Galaxy-Pocket+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneonright/SamsungGalaxyTab10.1/
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/SamsungGalaxyTab10.1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/SamsungGalaxyTab10.1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneonright/SamsungGalaxyTab10.1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/SamsungGalaxyTab10.1/Samsung-Galaxy-Tab10.1.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneonright/x-sense.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/._.DS_Store
#    creating: HHAR/Still_exp/Still exp/Phoneontop/111837-0/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/111837-0/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/3Renault-AH/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/3Renault-AH/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/3Renault-AH/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/3Renault-AH/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/3Renault-AH/Samsung-Galaxy-S3 Mini.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/gear_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/gear_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/gear_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/gear_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/gear_1/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/gear_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/gear_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/gear_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/gear_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/gear_2/Samsung-Galaxy-Gear.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-101/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-101/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-101/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-101/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-101/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-103/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-103/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-103/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-103/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-103/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-108/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-108/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-108/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-108/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-108/Samsung-Galaxy-S3.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-116/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-116/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-116/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-116/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-116/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-118/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-118/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-118/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-118/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-118/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-119/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-119/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-119/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-119/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-119/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-120/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-120/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-120/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-120/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-120/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-123/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-123/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-123/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-123/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-123/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-124/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-124/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-124/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-124/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-124/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-126/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-126/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-126/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-126/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-126/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-128/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-128/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-128/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-128/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-128/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-131/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-131/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-131/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-131/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-131/Samsung-Galaxy-Nexus.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-132/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-132/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-132/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-132/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-132/HTC-Nexus-One.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-133/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-133/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-133/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-133/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-133/Samsung-Galaxy-S+.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-135/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-135/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-135/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-135/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-135/HTC-Desire.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-137/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-137/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-137/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-137/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-137/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-139/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-139/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-139/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-139/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-139/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-140/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-140/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-140/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-140/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-140/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-141/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-141/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-141/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-141/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-141/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-144/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-144/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-144/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-144/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-144/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-149/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-149/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-149/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-149/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-149/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/it-151/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-151/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-151/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/it-151/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/it-151/LG-Nexus4.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/lg_1/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/lg_1/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/lg_1/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/lg_1/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/lg_1/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/lg_2/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/lg_2/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/lg_2/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/lg_2/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/lg_2/LG_G-Watch.csv
#    creating: HHAR/Still_exp/Still exp/Phoneontop/no-name/
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/no-name/.DS_Store
#    creating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/no-name/
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/Phoneontop/no-name/._.DS_Store
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/no-name/LG-Nexus4.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/no-name/LGE-Optimus-2X.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/no-name/Samsung-Galaxy-Pocket+.csv
#   inflating: HHAR/Still_exp/Still exp/Phoneontop/x-sense.csv
#   inflating: HHAR/Still_exp/Still exp/readme.txt
#   inflating: HHAR/Still_exp/__MACOSX/Still exp/._readme.txt
# Full DataFrame loaded successfully.
#
# First 5 rows of the full DataFrame:
#    Index   Arrival_Time        Creation_Time         x         y         z  \
# 0      0  1424696633908  1424696631913248572 -5.958191  0.688065  8.135345
# 1      1  1424696633909  1424696631918283972 -5.952240  0.670212  8.136536
# 2      2  1424696633918  1424696631923288855 -5.995087  0.653549  8.204376
# 3      3  1424696633919  1424696631928385290 -5.942718  0.676163  8.128204
# 4      4  1424696633929  1424696631933420691 -5.991516  0.641647  8.135345
#
#   User   Model    Device     gt
# 0    a  nexus4  nexus4_1  stand
# 1    a  nexus4  nexus4_1  stand
# 2    a  nexus4  nexus4_1  stand
# 3    a  nexus4  nexus4_1  stand
# 4    a  nexus4  nexus4_1  stand
# Full DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13062475 entries, 0 to 13062474
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Index          int64
#  1   Arrival_Time   int64
#  2   Creation_Time  int64
#  3   x              float64
#  4   y              float64
#  5   z              float64
#  6   User           object
#  7   Model          object
#  8   Device         object
#  9   gt             object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 996.6+ MB
# None

# %%
display(df_full.head())
# Out:
#    Index   Arrival_Time        Creation_Time         x         y         z  \
# 0      0  1424696633908  1424696631913248572 -5.958191  0.688065  8.135345
# 1      1  1424696633909  1424696631918283972 -5.952240  0.670212  8.136536
# 2      2  1424696633918  1424696631923288855 -5.995087  0.653549  8.204376
# 3      3  1424696633919  1424696631928385290 -5.942718  0.676163  8.128204
# 4      4  1424696633929  1424696631933420691 -5.991516  0.641647  8.135345
#
#   User   Model    Device     gt
# 0    a  nexus4  nexus4_1  stand
# 1    a  nexus4  nexus4_1  stand
# 2    a  nexus4  nexus4_1  stand
# 3    a  nexus4  nexus4_1  stand
# 4    a  nexus4  nexus4_1  stand

# %%
# Check for missing values
print("\nMissing values per column:")
display(df_full.isnull().sum())

# Handle missing values in the 'gt' column by dropping rows
df_full.dropna(subset=['gt'], inplace=True)

print("\nMissing values after dropping rows with missing 'gt':")
display(df_full.isnull().sum())

# Check data types
print("\nData types of columns:")
display(df_full.dtypes)
# Out:
# Missing values per column:
# Index                  0
# Arrival_Time           0
# Creation_Time          0
# x                      0
# y                      0
# z                      0
# User                   0
# Model                  0
# Device                 0
# gt               1783200
# dtype: int64
# Missing values after dropping rows with missing 'gt':
# Index            0
# Arrival_Time     0
# Creation_Time    0
# x                0
# y                0
# z                0
# User             0
# Model            0
# Device           0
# gt               0
# dtype: int64
# Data types of columns:
# Index              int64
# Arrival_Time       int64
# Creation_Time      int64
# x                float64
# y                float64
# z                float64
# User              object
# Model             object
# Device            object
# gt                object
# dtype: object

# %%
window_size = 50

# Calculate basic statistical features (mean, variance, std dev) for each window
df_full['x_mean'] = df_full['x'].rolling(window=window_size).mean()
df_full['y_mean'] = df_full['y'].rolling(window=window_size).mean()
df_full['z_mean'] = df_full['z'].rolling(window=window_size).mean()

df_full['x_var'] = df_full['x'].rolling(window=window_size).var()
df_full['y_var'] = df_full['y'].rolling(window=window_size).var()
df_full['z_var'] = df_full['z'].rolling(window=window_size).var()

df_full['x_std'] = df_full['x'].rolling(window=window_size).std()
df_full['y_std'] = df_full['y'].rolling(window=window_size).std()
df_full['z_std'] = df_full['z'].rolling(window=window_size).std()

# Drop the first `window_size - 1` rows as they will have NaN for the rolling features
df_full.dropna(inplace=True)

print("\nDataFrame with extracted features:")
display(df_full.head())
# Out:
# DataFrame with extracted features:
#     Index   Arrival_Time        Creation_Time         x         y         z  \
# 49     49  1424696634164  1424696632160105261 -5.947479  0.733292  8.157959
# 50     50  1424696634165  1424696632165140662 -5.902252  0.744003  8.097259
# 51     51  1424696634165  1424696632170176062 -5.930817  0.705917  8.107971
# 52     52  1424696634175  1424696632175241980 -5.904633  0.665451  8.097259
# 53     53  1424696634178  1424696632180277380 -5.891540  0.664261  8.072266
#
#    User   Model    Device     gt    x_mean    y_mean    z_mean     x_var  \
# 49    a  nexus4  nexus4_1  stand -5.936744  0.694944  8.128228  0.001139
# 50    a  nexus4  nexus4_1  stand -5.935625  0.696063  8.127466  0.001153
# 51    a  nexus4  nexus4_1  stand -5.935197  0.696777  8.126895  0.001148
# 52    a  nexus4  nexus4_1  stand -5.933387  0.697015  8.124753  0.001090
# 53    a  nexus4  nexus4_1  stand -5.932364  0.696777  8.123634  0.001123
#
#        y_var     z_var     x_std     y_std     z_std
# 49  0.002862  0.001706  0.033755  0.053497  0.041298
# 50  0.002909  0.001723  0.033956  0.053933  0.041515
# 51  0.002897  0.001729  0.033877  0.053820  0.041584
# 52  0.002878  0.001620  0.033018  0.053651  0.040249
# 53  0.002891  0.001675  0.033512  0.053772  0.040923

# %% [markdown]
# ## Adaptation of MET values
#
#
# Approximate MET values:
# - Sitting: 1.0-1.3 (Sedentary)
# - Standing: 1.3-1.8 (Sedentary to Light)
# - Walking: 2.0-5.0 (Light to Moderate)
# - Biking: 3.0-8.0+ (Moderate to Vigorous)
# - Stair Up: 4.0-8.0+ (Moderate to Vigorous)
# - Stair Down: 3.0-6.0 (Moderate)
#
# defining a simplified mapping to the four required MET classes using the actual labels from the dataset:
# - Sedentary (< 1.5 METs)
# - Light (1.5–3 METs)
# - Moderate (3–6 METs)
# - Vigorous (> 6 METs)

# %%
activity_to_met_class = {
    'sit': 'Sedentary',
    'stand': 'Sedentary',
    'walk': 'Light',
    'bike': 'Moderate',
    'stairsup': 'Moderate',
    'stairsdown': 'Moderate'
}

# Apply the mapping to met_class col
df_full['met_class'] = df_full['gt'].map(activity_to_met_class)

# Check the distribution MET classes
print("\nDistribution of MET classes:")
display(df_full['met_class'].value_counts())

print("\nDataFrame with 'met_class' column:")
display(df_full.head())
# Out:
# Distribution of MET classes:
# met_class
# Moderate     5243463
# Sedentary    3843362
# Light        2192401
# Name: count, dtype: int64
# DataFrame with 'met_class' column:
#     Index   Arrival_Time        Creation_Time         x         y         z  \
# 49     49  1424696634164  1424696632160105261 -5.947479  0.733292  8.157959
# 50     50  1424696634165  1424696632165140662 -5.902252  0.744003  8.097259
# 51     51  1424696634165  1424696632170176062 -5.930817  0.705917  8.107971
# 52     52  1424696634175  1424696632175241980 -5.904633  0.665451  8.097259
# 53     53  1424696634178  1424696632180277380 -5.891540  0.664261  8.072266
#
#    User   Model    Device     gt    x_mean    y_mean    z_mean     x_var  \
# 49    a  nexus4  nexus4_1  stand -5.936744  0.694944  8.128228  0.001139
# 50    a  nexus4  nexus4_1  stand -5.935625  0.696063  8.127466  0.001153
# 51    a  nexus4  nexus4_1  stand -5.935197  0.696777  8.126895  0.001148
# 52    a  nexus4  nexus4_1  stand -5.933387  0.697015  8.124753  0.001090
# 53    a  nexus4  nexus4_1  stand -5.932364  0.696777  8.123634  0.001123
#
#        y_var     z_var     x_std     y_std     z_std  met_class
# 49  0.002862  0.001706  0.033755  0.053497  0.041298  Sedentary
# 50  0.002909  0.001723  0.033956  0.053933  0.041515  Sedentary
# 51  0.002897  0.001729  0.033877  0.053820  0.041584  Sedentary
# 52  0.002878  0.001620  0.033018  0.053651  0.040249  Sedentary
# 53  0.002891  0.001675  0.033512  0.053772  0.040923  Sedentary

# %%
# Out:
# DataFrame sampled to 0.1% of original size.
#
# First 5 rows of the sampled DataFrame:
#     Index   Arrival_Time        Creation_Time         x         y          z  \
# 0  316643  1424783461561  1424783465042895362 -0.401215 -1.370956   9.120819
# 1   40227  1424777131681        2801692456000 -3.983902 -0.612908   8.580712
# 2   34639  1424779171336  1424779174809449676 -1.414062  0.083450  10.141998
# 3  135151  1424695257852       13131151454000  5.323507 -0.375890   8.319851
# 4  184378  1424789370842      353877453473000  0.497994  2.260126  10.371682
#
#   User       Model        Device     gt    x_mean    y_mean     z_mean  \
# 0    d      nexus4      nexus4_1   bike -0.632253 -1.465338  10.105031
# 1    i  samsungold  samsungold_1   walk -1.087912 -1.179848  10.664599
# 2    f      nexus4      nexus4_1  stand -1.402018  0.049625  10.150948
# 3    c      s3mini      s3mini_1   bike  4.285334 -1.488739   8.418540
# 4    e          s3          s3_2   bike  1.865754 -0.927993   9.109076
#
#       x_var     y_var      z_var     x_std     y_std     z_std  met_class
# 0  0.238998  0.199082   0.805968  0.488874  0.446186  0.897757   Moderate
# 1  3.747219  2.045266  11.220813  1.935773  1.430128  3.349748      Light
# 2  0.001216  0.001274   0.001808  0.034866  0.035694  0.042519  Sedentary
# 3  0.851397  1.070869   0.222422  0.922712  1.034828  0.471616   Moderate
# 4  0.542268  1.694502   2.862883  0.736388  1.301730  1.692006   Moderate

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

feature_columns = ['x_mean', 'y_mean', 'z_mean', 'x_var', 'y_var', 'z_var', 'x_std', 'y_std', 'z_std']
X = df_sampled[feature_columns]
y = df_sampled['met_class']

# Encode the 'met_class' to numerical representation with labelEncoder
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
print("\nDistribution of MET classes in y_train:")
display(pd.Series(y_train).value_counts(normalize=True))
print("\nDistribution of MET classes in y_test:")
display(pd.Series(y_test).value_counts(normalize=True))
# Out:
# Shape of X_train: (9023, 9)
# Shape of X_test: (2256, 9)
# Shape of y_train: (9023,)
# Shape of y_test: (2256,)
#
# Distribution of MET classes in y_train:
# 1    0.462706
# 2    0.345451
# 0    0.191843
# Name: proportion, dtype: float64
# Distribution of MET classes in y_test:
# 1    0.462766
# 2    0.345301
# 0    0.191933
# Name: proportion, dtype: float64

# %% [markdown]
# ## ML models
#
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# n_estimators=10
rf_model = RandomForestClassifier(n_estimators=10, random_state=42, n_jobs=-1)

# Train the model
print("Training Random Forest model...")
rf_model.fit(X_train, y_train)
print("Training complete.")

# Make predictions
print("Making predictions on testing data...")
y_pred_rf = rf_model.predict(X_test)
print("Predictions complete.")

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf, average='weighted')
recall_rf = recall_score(y_test, y_pred_rf, average='weighted')
f1_rf = f1_score(y_test, y_pred_rf, average='weighted')

print("\nRandom Forest Model Performance:")
print(f"Accuracy: {accuracy_rf:.4f}")
print(f"Precision: {precision_rf:.4f}")
print(f"Recall: {recall_rf:.4f}")
print(f"F1-score: {f1_rf:.4f}")
# Out:
# Training Random Forest model...
# Training complete.
# Making predictions on testing data...
# Predictions complete.
#
# Random Forest Model Performance:
# Accuracy: 0.8741
# Precision: 0.8740
# Recall: 0.8741
# F1-score: 0.8741

# %%
import joblib
import os

model_filename = 'random_forest_model.joblib'

# save model
joblib.dump(rf_model, model_filename)

print(f"Random Forest model saved to '{model_filename}'")
# Out:
# Random Forest model saved to 'random_forest_model.joblib'

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import time

# Use SGDClassifier for faster training on large datasets.
# With loss='hinge', it's equivalent to a linear SVM.
svm_model = SGDClassifier(loss='hinge', random_state=42, n_jobs=-1, early_stopping=True, max_iter=1000) # Added early_stopping and increased max_iter

# Train the model
print("Training SGDClassifier (Linear SVM) model...")
start_time = time.time()
svm_model.fit(X_train, y_train)
end_time = time.time()
print(f"Training complete in {end_time - start_time:.2f} seconds.")

# Make predictions
print("Making predictions on testing data...")
start_time = time.time()
y_pred_svm = svm_model.predict(X_test)
end_time = time.time()
print(f"Predictions complete in {end_time - start_time:.2f} seconds.")

# Evaluate the model
# Use zero_division=0 to handle cases where a class has no predicted samples
accuracy_svm = accuracy_score(y_test, y_pred_svm)
precision_svm = precision_score(y_test, y_pred_svm, average='weighted', zero_division=0)
recall_svm = recall_score(y_test, y_pred_svm, average='weighted', zero_division=0)
f1_svm = f1_score(y_test, y_pred_svm, average='weighted', zero_division=0)

print("\nSGDClassifier (Linear SVM) Model Performance:")
print(f"Accuracy: {accuracy_svm:.4f}")
print(f"Precision: {precision_svm:.4f}")
print(f"Recall: {recall_svm:.4f}")
print(f"F1-score: {f1_svm:.4f}")
# Out:
# Training SGDClassifier (Linear SVM) model...
# Training complete in 0.04 seconds.
# Making predictions on testing data...
# Predictions complete in 0.00 seconds.
#
# SGDClassifier (Linear SVM) Model Performance:
# Accuracy: 0.7496
# Precision: 0.6456
# Recall: 0.7496
# F1-score: 0.6776

# %%
import joblib
import os

model_filename_svm = 'svm_model.joblib'

# Save the SVM model
joblib.dump(svm_model, model_filename_svm)

print(f"SVM model saved to '{model_filename_svm}'")
# Out:
# SVM model saved to 'svm_model.joblib'

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import time

# Initialize the Gradient Boosting Classifier
# Using a moderate number of estimators for a balance of performance and speed
gb_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Train the model
print("Training Gradient Boosting model...")
start_time = time.time()
gb_model.fit(X_train, y_train)
end_time = time.time()
print(f"Training complete in {end_time - start_time:.2f} seconds.")

# Make predictions
print("Making predictions on testing data...")
start_time = time.time()
y_pred_gb = gb_model.predict(X_test)
end_time = time.time()
print(f"Predictions complete in {end_time - start_time:.2f} seconds.")

# Evaluate the model
# Use zero_division=0 to handle cases where a class has no predicted samples
accuracy_gb = accuracy_score(y_test, y_pred_gb)
precision_gb = precision_score(y_test, y_pred_gb, average='weighted', zero_division=0)
recall_gb = recall_score(y_test, y_pred_gb, average='weighted', zero_division=0)
f1_gb = f1_score(y_test, y_pred_gb, average='weighted', zero_division=0)

print("\nGradient Boosting Model Performance:")
print(f"Accuracy: {accuracy_gb:.4f}")
print(f"Precision: {precision_gb:.4f}")
print(f"Recall: {recall_gb:.4f}")
print(f"F1-score: {f1_gb:.4f}")
# Out:
# Training Gradient Boosting model...
# Training complete in 18.86 seconds.
# Making predictions on testing data...
# Predictions complete in 0.01 seconds.
#
# Gradient Boosting Model Performance:
# Accuracy: 0.8688
# Precision: 0.8657
# Recall: 0.8688
# F1-score: 0.8659

# %%
import joblib
import os

model_filename_gb = 'gradient_boosting_model.joblib'

# Save the Gradient Boosting model
joblib.dump(gb_model, model_filename_gb)

print(f"Gradient Boosting model saved to '{model_filename_gb}'")
# Out:
# Gradient Boosting model saved to 'gradient_boosting_model.joblib'

# %% [markdown]
# ### Gradient Boosting
#
# ### Neural Network models

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import time

# Define the Neural Network model
# Using a simple architecture for efficiency
model = keras.Sequential([
    keras.layers.InputLayer(input_shape=(X_train.shape[1],)), # Input layer matching the number of features
    keras.layers.Dense(64, activation='relu'), # Hidden layer with ReLU activation
    keras.layers.Dropout(0.2), # Dropout for regularization
    keras.layers.Dense(32, activation='relu'), # Another hidden layer
    keras.layers.Dropout(0.2), # Dropout for regularization
    keras.layers.Dense(len(np.unique(y_train)), activation='softmax') # Output layer with softmax for multi-class classification
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', # Use sparse_categorical_crossentropy for integer labels
              metrics=['accuracy'])

# Train the model
print("Training Neural Network model...")
start_time = time.time()
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=1) # Train for a reasonable number of epochs
end_time = time.time()
print(f"Training complete in {end_time - start_time:.2f} seconds.")

# Evaluate the model
print("Evaluating Neural Network model...")
start_time = time.time()
loss, accuracy_nn = model.evaluate(X_test, y_test, verbose=0)
end_time = time.time()
print(f"Evaluation complete in {end_time - start_time:.2f} seconds.")

# Make predictions
y_pred_nn_probs = model.predict(X_test)
y_pred_nn = np.argmax(y_pred_nn_probs, axis=1)


# Evaluate the model using scikit-learn metrics
precision_nn = precision_score(y_test, y_pred_nn, average='weighted', zero_division=0)
recall_nn = recall_score(y_test, y_pred_nn, average='weighted', zero_division=0)
f1_nn = f1_score(y_test, y_pred_nn, average='weighted', zero_division=0)


print("\nNeural Network Model Performance:")
print(f"Accuracy: {accuracy_nn:.4f}")
print(f"Precision: {precision_nn:.4f}")
print(f"Recall: {recall_nn:.4f}")
print(f"F1-score: {f1_nn:.4f}")
# Out:
# Training Neural Network model...
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6155 - loss: 0.8292 - val_accuracy: 0.7773 - val_loss: 0.4187
# Epoch 2/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7740 - loss: 0.4733 - val_accuracy: 0.8161 - val_loss: 0.3628
# Epoch 3/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8061 - loss: 0.4095 - val_accuracy: 0.8133 - val_loss: 0.3479
# Epoch 4/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8136 - loss: 0.3794 - val_accuracy: 0.8349 - val_loss: 0.3401
# Epoch 5/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8302 - loss: 0.3587 - val_accuracy: 0.8410 - val_loss: 0.3305
# Epoch 6/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8309 - loss: 0.3642 - val_accuracy: 0.8343 - val_loss: 0.3309
# Epoch 7/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8310 - loss: 0.3443 - val_accuracy: 0.8471 - val_loss: 0.3271
# Epoch 8/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8359 - loss: 0.3413 - val_accuracy: 0.8493 - val_loss: 0.3204
# Epoch 9/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8307 - loss: 0.3540 - val_accuracy: 0.8526 - val_loss: 0.3218
# Epoch 10/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8355 - loss: 0.3414 - val_accuracy: 0.8488 - val_loss: 0.3254
# Epoch 11/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8426 - loss: 0.3337 - val_accuracy: 0.8488 - val_loss: 0.3185
# Epoch 12/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8390 - loss: 0.3378 - val_accuracy: 0.8482 - val_loss: 0.3174
# Epoch 13/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8424 - loss: 0.3325 - val_accuracy: 0.8504 - val_loss: 0.3222
# Epoch 14/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8450 - loss: 0.3296 - val_accuracy: 0.8454 - val_loss: 0.3191
# Epoch 15/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8581 - loss: 0.3131 - val_accuracy: 0.8532 - val_loss: 0.3098
# Epoch 16/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8543 - loss: 0.3146 - val_accuracy: 0.8521 - val_loss: 0.3110
# Epoch 17/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8526 - loss: 0.3178 - val_accuracy: 0.8604 - val_loss: 0.3085
# Epoch 18/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8544 - loss: 0.3211 - val_accuracy: 0.8543 - val_loss: 0.3091
# Epoch 19/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8557 - loss: 0.3117 - val_accuracy: 0.8504 - val_loss: 0.3123
# Epoch 20/20
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8591 - loss: 0.3031 - val_accuracy: 0.8515 - val_loss: 0.3107
# Training complete in 22.30 seconds.
# Evaluating Neural Network model...
# Evaluation complete in 0.21 seconds.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Neural Network Model Performance:
# Accuracy: 0.8648
# Precision: 0.8650
# Recall: 0.8648
# F1-score: 0.8507

# %%
import os

# Define the filename for the Keras model
model_filename_nn = 'neural_network_model.keras'

# Save the model in the native Keras format
model.save(model_filename_nn)

print(f"Neural Network model saved to '{model_filename_nn}'")
# Out:
# Neural Network model saved to 'neural_network_model.keras'

# %%
import pandas as pd

# Create a dictionary to store the performance metrics
performance_data = {
    'Model': ['Random Forest', 'Linear SVM (SGDClassifier)', 'Gradient Boosting', 'Neural Network'],
    'Accuracy': [accuracy_rf, accuracy_svm, accuracy_gb, accuracy_nn],
    'Precision (Weighted)': [precision_rf, precision_svm, precision_gb, precision_nn],
    'Recall (Weighted)': [recall_rf, recall_svm, recall_gb, recall_nn],
    'F1-score (Weighted)': [f1_rf, f1_svm, f1_gb, f1_nn]
}

# Create a pandas DataFrame from the performance data
performance_df = pd.DataFrame(performance_data)

# Display the performance comparison table
print("Model Performance Comparison:")
display(performance_df)
# Out:
# Model Performance Comparison:
#                         Model  Accuracy  Precision (Weighted)  \
# 0               Random Forest  0.874113              0.874034
# 1  Linear SVM (SGDClassifier)  0.749557              0.645567
# 2           Gradient Boosting  0.868794              0.865678
# 3              Neural Network  0.864805              0.864993
#
#    Recall (Weighted)  F1-score (Weighted)
# 0           0.874113             0.874057
# 1           0.749557             0.677550
# 2           0.868794             0.865933
# 3           0.864805             0.850731

# %% [markdown]
# ## Model Selection
#
# Based on the performance comparison, the **Random Forest** model demonstrated the highest performance across all evaluated metrics (Accuracy, Precision, Recall, and F1-score) on the sampled dataset. Therefore, the Random Forest model is selected as the best model for this activity recognition task among the models trained.
